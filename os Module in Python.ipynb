# %%
import os

if(not os.path.exists("data")):
    os.mkdir("data")

for i in range(0, 100):
    os.mkdir(f"data/Day{i+1}")

# %%
import os

# List the contents of the current working directory
print("Current Working Directory:", os.getcwd())
folders = os.listdir(".")  # List folders/files in the current working directory

print("Contents of current directory:", folders)

for i in range(0, 100):
    old_path = f"Day{i+1}"  # Reference files directly
    new_path = f"Day {i+1}"
    
    # Check if the file exists before renaming
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"Renamed: '{old_path}' -> '{new_path}'")
    else:
        print(f"Skipping: '{old_path}' does not exist.")
# Out:
# Current Working Directory: e:\Python\data
# Contents of current directory: ['Day1', 'Day10', 'Day100', 'Day11', 'Day12', 'Day13', 'Day14', 'Day15', 'Day16', 'Day17', 'Day18', 'Day19', 'Day2', 'Day20', 'Day21', 'Day22', 'Day23', 'Day24', 'Day25', 'Day26', 'Day27', 'Day28', 'Day29', 'Day3', 'Day30', 'Day31', 'Day32', 'Day33', 'Day34', 'Day35', 'Day36', 'Day37', 'Day38', 'Day39', 'Day4', 'Day40', 'Day41', 'Day42', 'Day43', 'Day44', 'Day45', 'Day46', 'Day47', 'Day48', 'Day49', 'Day5', 'Day50', 'Day51', 'Day52', 'Day53', 'Day54', 'Day55', 'Day56', 'Day57', 'Day58', 'Day59', 'Day6', 'Day60', 'Day61', 'Day62', 'Day63', 'Day64', 'Day65', 'Day66', 'Day67', 'Day68', 'Day69', 'Day7', 'Day70', 'Day71', 'Day72', 'Day73', 'Day74', 'Day75', 'Day76', 'Day77', 'Day78', 'Day79', 'Day8', 'Day80', 'Day81', 'Day82', 'Day83', 'Day84', 'Day85', 'Day86', 'Day87', 'Day88', 'Day89', 'Day9', 'Day90', 'Day91', 'Day92', 'Day93', 'Day94', 'Day95', 'Day96', 'Day97', 'Day98', 'Day99']
# Renamed: 'Day1' -> 'Day 1'
# Renamed: 'Day2' -> 'Day 2'
# Renamed: 'Day3' -> 'Day 3'
# Renamed: 'Day4' -> 'Day 4'
# Renamed: 'Day5' -> 'Day 5'
# Renamed: 'Day6' -> 'Day 6'
# Renamed: 'Day7' -> 'Day 7'
# Renamed: 'Day8' -> 'Day 8'
# Renamed: 'Day9' -> 'Day 9'
# Renamed: 'Day10' -> 'Day 10'
# Renamed: 'Day11' -> 'Day 11'
# Renamed: 'Day12' -> 'Day 12'
# Renamed: 'Day13' -> 'Day 13'
# Renamed: 'Day14' -> 'Day 14'
# Renamed: 'Day15' -> 'Day 15'
# Renamed: 'Day16' -> 'Day 16'
# Renamed: 'Day17' -> 'Day 17'
# Renamed: 'Day18' -> 'Day 18'
# Renamed: 'Day19' -> 'Day 19'
# Renamed: 'Day20' -> 'Day 20'
# Renamed: 'Day21' -> 'Day 21'
# Renamed: 'Day22' -> 'Day 22'
# Renamed: 'Day23' -> 'Day 23'
# Renamed: 'Day24' -> 'Day 24'
# Renamed: 'Day25' -> 'Day 25'
# Renamed: 'Day26' -> 'Day 26'
# Renamed: 'Day27' -> 'Day 27'
# Renamed: 'Day28' -> 'Day 28'
# Renamed: 'Day29' -> 'Day 29'
# Renamed: 'Day30' -> 'Day 30'
# Renamed: 'Day31' -> 'Day 31'
# Renamed: 'Day32' -> 'Day 32'
# Renamed: 'Day33' -> 'Day 33'
# Renamed: 'Day34' -> 'Day 34'
# Renamed: 'Day35' -> 'Day 35'
# Renamed: 'Day36' -> 'Day 36'
# Renamed: 'Day37' -> 'Day 37'
# Renamed: 'Day38' -> 'Day 38'
# Renamed: 'Day39' -> 'Day 39'
# Renamed: 'Day40' -> 'Day 40'
# Renamed: 'Day41' -> 'Day 41'
# Renamed: 'Day42' -> 'Day 42'
# Renamed: 'Day43' -> 'Day 43'
# Renamed: 'Day44' -> 'Day 44'
# Renamed: 'Day45' -> 'Day 45'
# Renamed: 'Day46' -> 'Day 46'
# Renamed: 'Day47' -> 'Day 47'
# Renamed: 'Day48' -> 'Day 48'
# Renamed: 'Day49' -> 'Day 49'
# Renamed: 'Day50' -> 'Day 50'
# Renamed: 'Day51' -> 'Day 51'
# Renamed: 'Day52' -> 'Day 52'
# Renamed: 'Day53' -> 'Day 53'
# Renamed: 'Day54' -> 'Day 54'
# Renamed: 'Day55' -> 'Day 55'
# Renamed: 'Day56' -> 'Day 56'
# Renamed: 'Day57' -> 'Day 57'
# Renamed: 'Day58' -> 'Day 58'
# Renamed: 'Day59' -> 'Day 59'
# Renamed: 'Day60' -> 'Day 60'
# Renamed: 'Day61' -> 'Day 61'
# Renamed: 'Day62' -> 'Day 62'
# Renamed: 'Day63' -> 'Day 63'
# Renamed: 'Day64' -> 'Day 64'
# Renamed: 'Day65' -> 'Day 65'
# Renamed: 'Day66' -> 'Day 66'
# Renamed: 'Day67' -> 'Day 67'
# Renamed: 'Day68' -> 'Day 68'
# Renamed: 'Day69' -> 'Day 69'
# Renamed: 'Day70' -> 'Day 70'
# Renamed: 'Day71' -> 'Day 71'
# Renamed: 'Day72' -> 'Day 72'
# Renamed: 'Day73' -> 'Day 73'
# Renamed: 'Day74' -> 'Day 74'
# Renamed: 'Day75' -> 'Day 75'
# Renamed: 'Day76' -> 'Day 76'
# Renamed: 'Day77' -> 'Day 77'
# Renamed: 'Day78' -> 'Day 78'
# Renamed: 'Day79' -> 'Day 79'
# Renamed: 'Day80' -> 'Day 80'
# Renamed: 'Day81' -> 'Day 81'
# Renamed: 'Day82' -> 'Day 82'
# Renamed: 'Day83' -> 'Day 83'
# Renamed: 'Day84' -> 'Day 84'
# Renamed: 'Day85' -> 'Day 85'
# Renamed: 'Day86' -> 'Day 86'
# Renamed: 'Day87' -> 'Day 87'
# Renamed: 'Day88' -> 'Day 88'
# Renamed: 'Day89' -> 'Day 89'
# Renamed: 'Day90' -> 'Day 90'
# Renamed: 'Day91' -> 'Day 91'
# Renamed: 'Day92' -> 'Day 92'
# Renamed: 'Day93' -> 'Day 93'
# Renamed: 'Day94' -> 'Day 94'
# Renamed: 'Day95' -> 'Day 95'
# Renamed: 'Day96' -> 'Day 96'
# Renamed: 'Day97' -> 'Day 97'
# Renamed: 'Day98' -> 'Day 98'
# Renamed: 'Day99' -> 'Day 99'
# Renamed: 'Day100' -> 'Day 100'

# %%
import os 
folders = os.listdir("e:\Python\data")

print(os.getcwd())
os.chdir("e:\Python")
print(os.getcwd())

for folder in folders:
    print(folder)
    print(os.listdir(f"data/{folder}"))
# Out:
# e:\Python\data
# e:\Python
# Day 1
# []
# Day 10
# []
# Day 100
# []
# Day 11
# []
# Day 12
# []
# Day 13
# []
# Day 14
# []
# Day 15
# []
# Day 16
# []
# Day 17
# []
# Day 18
# []
# Day 19
# []
# Day 2
# []
# Day 20
# []
# Day 21
# []
# Day 22
# []
# Day 23
# []
# Day 24
# []
# Day 25
# []
# Day 26
# []
# Day 27
# []
# Day 28
# []
# Day 29
# []
# Day 3
# []
# Day 30
# []
# Day 31
# []
# Day 32
# []
# Day 33
# []
# Day 34
# []
# Day 35
# []
# Day 36
# []
# Day 37
# []
# Day 38
# []
# Day 39
# []
# Day 4
# []
# Day 40
# []
# Day 41
# []
# Day 42
# []
# Day 43
# []
# Day 44
# []
# Day 45
# []
# Day 46
# []
# Day 47
# []
# Day 48
# []
# Day 49
# []
# Day 5
# []
# Day 50
# []
# Day 51
# []
# Day 52
# []
# Day 53
# []
# Day 54
# []
# Day 55
# []
# Day 56
# []
# Day 57
# []
# Day 58
# []
# Day 59
# []
# Day 6
# []
# Day 60
# []
# Day 61
# []
# Day 62
# []
# Day 63
# []
# Day 64
# []
# Day 65
# []
# Day 66
# []
# Day 67
# []
# Day 68
# []
# Day 69
# []
# Day 7
# []
# Day 70
# []
# Day 71
# []
# Day 72
# []
# Day 73
# []
# Day 74
# []
# Day 75
# []
# Day 76
# []
# Day 77
# []
# Day 78
# []
# Day 79
# []
# Day 8
# []
# Day 80
# []
# Day 81
# []
# Day 82
# []
# Day 83
# []
# Day 84
# []
# Day 85
# []
# Day 86
# []
# Day 87
# []
# Day 88
# []
# Day 89
# []
# Day 9
# []
# Day 90
# []
# Day 91
# []
# Day 92
# []
# Day 93
# []
# Day 94
# []
# Day 95
# []
# Day 96
# []
# Day 97
# []
# Day 98
# []
# Day 99
# []
