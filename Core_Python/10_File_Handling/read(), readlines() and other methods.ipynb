# %%
# Example 1

f = open('../clutteredFolder/myfile1.txt','r')
while True:
    line = f.readline()
    if not line:
        print(line, type(line))
        break
    print(line)
# Out:
# File Handling in Python
#
# File handling allows Python programs to read, write, and manipulate files (text or binary).
#  <class 'str'>

# %%
# Example 2

f = open('../clutteredFolder/myfile2.txt','r')
i = 0
while True:
    i += 1
    line = f.readline()
    if not line:
        print(line, type(line))
        break
    m1 = int(line.split(",")[0])
    m2 = int(line.split(",")[1])
    m3 = int(line.split(",")[2])
    print(f"Marks of student {i} in maths is: {m1}")
    print(f"Marks of student {i} in scienece is: {m2}")
    print(f"Marks of student {i} in english is: {m3}")
# Out:
# Marks of student 1 in maths is: 14
# Marks of student 1 in scienece is: 20
# Marks of student 1 in english is: 25
#  <class 'str'>

# %%
# Example 3

f = open('../clutteredFolder/myfile3.txt','w')
lines = ['line 1\n','line 2\n','line 3\n']
f.writelines(lines)
f.close()

# %%
# Example 4

f = open('../clutteredFolder/myfile4.txt','w')
lines = ['line 1','line 2','line 3']
for line in lines:
    f.write(line + '\n')
f.close()
