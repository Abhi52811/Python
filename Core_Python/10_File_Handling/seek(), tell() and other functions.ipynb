# %% [markdown]
# File Cursor: seek() and tell()

# %%
with open('../clutteredFolder/myfile.txt', "r") as f:
    print(type(f))
    # Move to the 10 byte of the files
    f.seek(13)
    # return the current position within the file, in bytes
    # basically return the number of bytes of seek 
    print(f.tell())
    # Read the next 10 bytes
    data = f.read(30)
    print(data)
# Out:
# <class '_io.TextIOWrapper'>
# 13
#
#
# This is new data.

# %%
with open('../clutteredFolder/myfile.txt', "w") as f:
    f.write('Hello world')
    # using truncate we can specify the size of characters
    # we want in the file
    f.truncate(5)

with open('myfile4.txt','r') as f:
    print(f.read())
# Out:
# Hello
